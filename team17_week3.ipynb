# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# read a diabetes_model.csv file from seaborn library
df = pd.read_csv('diabetes_model.csv')
# count plot outcomes
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %%
sns.countplot(x='Outcome',data=df)
plt.show()

# %% [markdown]
# # Analyse effect of age on outcomes using boxplot

# %%
sns.boxplot(x=df['Outcome'],y=df['Age'],data=df)
plt.title('Effect of age on outcome')
# Out:
# Text(0.5, 1.0, 'Effect of age on outcome')

# %% [markdown]
# # Check for chances of getting diabetes if it is common in family,using diabetes pedigree function

# %%
sns.violinplot(x=df['Outcome'],y=df['DiabetesPedigreeFunction'],data=df)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='DiabetesPedigreeFunction'>

# %% [markdown]
# # Check for the relationship with insulin & glucose and group the datapoints by outcomes

# %%
sns.scatterplot(x=df['Insulin'],y=df['Glucose'],data=df,hue=df['Outcome'])
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Glucose'>

# %% [markdown]
# # Create a heatmap on Correlation of features in the data

# %%
sns.heatmap(df.corr())
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5]),
#  [Text(0.5, 0, 'Pregnancies'),
#   Text(1.5, 0, 'Glucose'),
#   Text(2.5, 0, 'BloodPressure'),
#   Text(3.5, 0, 'SkinThickness'),
#   Text(4.5, 0, 'Insulin'),
#   Text(5.5, 0, 'BMI'),
#   Text(6.5, 0, 'DiabetesPedigreeFunction'),
#   Text(7.5, 0, 'Age'),
#   Text(8.5, 0, 'Outcome')])
